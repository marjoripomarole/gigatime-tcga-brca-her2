# %% [markdown]
# # Clinical HER2 Classifier Results
#
# Classifier-only report for the TCGA-BRCA GigaTIME HER2 pilot.
#
# **Plain-language bottom line:** the first real classifier is working, but it is not clinically reliable yet. The strongest image-derived result is HER2-low versus HER2-zero. HER2-positive classification from GigaTIME/H&E features is weak, and full three-class prediction is still at chance.

# %% [markdown]
# ## What Was Trained
#
# - Input: slide-level GigaTIME virtual mIF features from the 256-tile run.
# - Labels: clinical HER2 groups from TCGA IHC/ISH fields.
# - Models: regularized logistic classifier and nearest-centroid baseline.
# - Evaluation: leave-one-out cross-validation.
#
# Every reported prediction is held out: each slide is predicted after that slide is removed from the training set.

# %% [markdown]
# ## Feature Sets
#
# | Feature set | Number of features | Example features |
# | --- | --- | --- |
# | GigaTIME mean channels | 23 | mean_DAPI, mean_TRITC, mean_Cy5, mean_PD-1, mean_CD14, mean_CD4, mean_T-bet, mean_CD34... |
# | GigaTIME mean + fraction channels | 46 | mean_DAPI, mean_TRITC, mean_Cy5, mean_PD-1, mean_CD14, mean_CD4, mean_T-bet, mean_CD34... |
# | Interpretable marker means | 10 | mean_CD3, mean_CD8, mean_CD4, mean_CD20, mean_CD68, mean_CD11c, mean_PD-1, mean_PD-L1... |
# | Virtual programs | 5 | virtual_myeloid_checkpoint, virtual_t_cell_checkpoint, virtual_all_immune_checkpoint, virtual_proliferation, virtual_epithelial |
# | ERBB2 RNA reference | 1 | erbb2_tpm |

# %% [markdown]
# ## Best GigaTIME/H&E Classifier Results
#
# | Task | Best feature set | N | Accuracy | Balanced accuracy | Macro AUC | Sensitivity | Specificity |
# | --- | --- | --- | --- | --- | --- | --- | --- |
# | HER2-low vs HER2-zero | GigaTIME mean + fraction channels | 20 | 0.800 | 0.800 | 0.870 | 0.700 | 0.900 |
# | HER2-positive vs HER2-negative | GigaTIME mean + fraction channels | 30 | 0.533 | 0.475 | 0.430 | 0.300 | 0.650 |
# | HER2-positive vs HER2-low vs HER2-zero | GigaTIME mean + fraction channels | 30 | 0.333 | 0.333 | 0.555 |  |  |
#
# **Interpretation:** the HER2-low versus HER2-zero classifier is the only promising image-derived result so far.

# %% [markdown]
# ## Performance Plot
#
# ![Classifier balanced accuracy](../docs/assets/clinical_her2_classifier_baseline/classifier_balanced_accuracy.png)

# %% [markdown]
# ## Confusion Matrices
#
# These matrices show the best GigaTIME/H&E regularized logistic model for each task. They do not use ERBB2 RNA.
#
# ### HER2-low versus HER2-zero
#
# ![HER2-low versus HER2-zero confusion matrix](../docs/assets/clinical_her2_classifier_baseline/confusion_her2_low_vs_zero.png)
#
# ### HER2-positive versus HER2-negative
#
# ![HER2-positive versus HER2-negative confusion matrix](../docs/assets/clinical_her2_classifier_baseline/confusion_her2_positive_vs_negative.png)
#
# ### Three-class HER2 group
#
# ![Three-class HER2 confusion matrix](../docs/assets/clinical_her2_classifier_baseline/confusion_her2_three_class.png)

# %% [markdown]
# ## ERBB2 RNA Reference
#
# ERBB2 RNA is included only as a non-H&E reference. It is not an image classifier.
#
# | Task | N | Accuracy | Balanced accuracy | Macro AUC | Sensitivity | Specificity |
# | --- | --- | --- | --- | --- | --- | --- |
# | HER2-low vs HER2-zero | 20 | 0.650 | 0.650 | 0.690 | 0.700 | 0.600 |
# | HER2-positive vs HER2-negative | 30 | 0.900 | 0.850 | 0.800 | 0.700 | 1.000 |
# | HER2-positive vs HER2-low vs HER2-zero | 30 | 0.233 | 0.233 | 0.567 |  |  |
#
# This matters because ERBB2 RNA performs much better for HER2-positive versus HER2-negative than the current GigaTIME/H&E features. So the labels contain HER2 signal, but the current image-derived model is not capturing that HER2-positive signal reliably yet.

# %% [markdown]
# ## All Regularized Logistic Results
#
# | Task | Feature set | N | Accuracy | Balanced accuracy | Macro AUC |
# | --- | --- | --- | --- | --- | --- |
# | HER2-low vs HER2-zero | GigaTIME mean + fraction channels | 20 | 0.800 | 0.800 | 0.870 |
# | HER2-low vs HER2-zero | GigaTIME mean channels | 20 | 0.700 | 0.700 | 0.710 |
# | HER2-low vs HER2-zero | Virtual programs | 20 | 0.700 | 0.700 | 0.770 |
# | HER2-low vs HER2-zero | ERBB2 RNA reference | 20 | 0.650 | 0.650 | 0.690 |
# | HER2-low vs HER2-zero | Interpretable marker means | 20 | 0.600 | 0.600 | 0.750 |
# | HER2-positive vs HER2-negative | ERBB2 RNA reference | 30 | 0.900 | 0.850 | 0.800 |
# | HER2-positive vs HER2-negative | GigaTIME mean + fraction channels | 30 | 0.533 | 0.475 | 0.430 |
# | HER2-positive vs HER2-negative | Virtual programs | 30 | 0.633 | 0.475 | 0.125 |
# | HER2-positive vs HER2-negative | Interpretable marker means | 30 | 0.600 | 0.450 | 0.260 |
# | HER2-positive vs HER2-negative | GigaTIME mean channels | 30 | 0.533 | 0.400 | 0.090 |
# | HER2-positive vs HER2-low vs HER2-zero | GigaTIME mean + fraction channels | 30 | 0.333 | 0.333 | 0.555 |
# | HER2-positive vs HER2-low vs HER2-zero | Interpretable marker means | 30 | 0.333 | 0.333 | 0.488 |
# | HER2-positive vs HER2-low vs HER2-zero | Virtual programs | 30 | 0.300 | 0.300 | 0.463 |
# | HER2-positive vs HER2-low vs HER2-zero | GigaTIME mean channels | 30 | 0.233 | 0.233 | 0.405 |
# | HER2-positive vs HER2-low vs HER2-zero | ERBB2 RNA reference | 30 | 0.233 | 0.233 | 0.567 |

# %% [markdown]
# ## Example Held-Out Mistakes
#
# | Task | Case | True label | Predicted label | Model confidence |
# | --- | --- | --- | --- | --- |
# | HER2-low vs HER2-zero | TCGA-A2-A0T6 | HER2-low | HER2-zero | 0.729 |
# | HER2-low vs HER2-zero | TCGA-A1-A0SK | HER2-zero | HER2-low | 0.810 |
# | HER2-low vs HER2-zero | TCGA-A1-A0SP | HER2-zero | HER2-low | 0.506 |
# | HER2-low vs HER2-zero | TCGA-A2-A0EW | HER2-zero | HER2-low | 0.999 |
# | HER2-positive vs HER2-negative | TCGA-A1-A0SM | HER2-positive | HER2-negative | 0.625 |
# | HER2-positive vs HER2-negative | TCGA-A2-A04U | HER2-positive | HER2-negative | 0.868 |
# | HER2-positive vs HER2-negative | TCGA-A2-A04X | HER2-positive | HER2-negative | 0.831 |
# | HER2-positive vs HER2-negative | TCGA-A2-A0EQ | HER2-positive | HER2-negative | 0.997 |
# | HER2-positive vs HER2-negative | TCGA-A2-A0EY | HER2-positive | HER2-negative | 0.738 |
# | HER2-positive vs HER2-negative | TCGA-A2-A0SY | HER2-positive | HER2-negative | 0.936 |
# | HER2-positive vs HER2-negative | TCGA-A2-A0T1 | HER2-positive | HER2-negative | 0.830 |
# | HER2-positive vs HER2-negative | TCGA-5T-A9QA | HER2-negative | HER2-positive | 0.629 |
# | HER2-positive vs HER2-negative | TCGA-A2-A04T | HER2-negative | HER2-positive | 0.530 |
# | HER2-positive vs HER2-negative | TCGA-A2-A0EN | HER2-negative | HER2-positive | 0.616 |
# | HER2-positive vs HER2-negative | TCGA-A1-A0SK | HER2-negative | HER2-positive | 0.687 |
# | HER2-positive vs HER2-negative | TCGA-A2-A0EU | HER2-negative | HER2-positive | 0.965 |
# | HER2-positive vs HER2-negative | TCGA-A2-A0EV | HER2-negative | HER2-positive | 0.520 |
# | HER2-positive vs HER2-negative | TCGA-A2-A0T0 | HER2-negative | HER2-positive | 0.964 |
#
# Mistakes are useful here. They tell us what to inspect next: the H&E tiles and virtual channels for cases the classifier confuses.

# %% [markdown]
# ## Scientific Interpretation
#
# What we gained:
#
# - We now have a real classifier baseline, not only group-average comparisons.
# - The HER2-low versus HER2-zero result matches the earlier group-average pattern.
# - The current slide-level GigaTIME features are not enough for reliable HER2-positive diagnosis.
# - The full three-class problem is not solved.
#
# What this means clinically:
#
# - This does not support clinical HER2 diagnosis yet.
# - It does support a sharper research hypothesis: GigaTIME may capture a microenvironment signal that separates HER2-low from HER2-zero better than it captures HER2-positive status.

# %% [markdown]
# ## Next Classifier Step
#
# The next model should improve the input, not just swap the classifier:
#
# 1. Restrict features to tumor-rich tiles instead of all tissue tiles.
# 2. Add tile distribution features: percentiles, maximum signal, and heterogeneity.
# 3. Add H&E tile embeddings if available.
# 4. Move toward multiple-instance learning after tile-level features are organized.
# 5. Evaluate with nested cross-validation or a separate held-out test set before making stronger claims.
